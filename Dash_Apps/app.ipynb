# %%
import dash
import dash_bootstrap_components as dbc
from dash import Input, Output, dcc, html

# %%
import dash
import dash_bootstrap_components as dbc
from dash import Input, Output, dcc, html

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
home=dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
# the style arguments for the sidebar. We use position:fixed and a fixed width
# SIDEBAR_STYLE = {
#     "position": "absolute",
#     "top": 0,
#     "left": 0,
#     "bottom": 0,
#     "width": "12rem",
#     "padding": "2rem 1rem",
#     "background-color": "#f8f9fa",
# }

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "18rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}

sidebar = html.Div(
    [
        html.Img(src=r"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRdXp6BcRI1EEjzO07AoWD7IzzA7P77po_UUn1rxtE&s", alt='image'),
        html.H4("Data Analyzer WebApp V5.6", className="display-4",style={"font-size": "1.5rem","color":"green"}),
        html.Hr(),
        dbc.Nav(
            [
                dbc.NavLink("Home", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/", active="exact"),
                dbc.NavLink("DeviceList", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/DeviceList", active="exact"),
                dbc.NavLink("JSP/DBEM", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/JSP/DBEM", active="exact"),
                dbc.NavLink("SmartMeter", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/SmartMeter", active="exact"),
                dbc.NavLink("HSM", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/HSM", active="exact"),
                dbc.NavLink("DBEM+JSP", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/DBEM+JSP", active="exact"),
                dbc.NavLink("Solar", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Solar", active="exact"),
                dbc.NavLink("HeatMap", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/HeatMap", active="exact"),
                dbc.NavLink("Reports", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Reports", active="exact"),
                dbc.NavLink("Data Hours", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Data Hours", active="exact"),
                dbc.NavLink("MetaData", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/MetaData", active="exact"),
                dbc.NavLink("Devices-Info", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Devices-Info", active="exact")
                
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style={
        "position": "absolute",
        "top": 0,
        "left": 0,
        "bottom": 0,
        "width": "12rem",
        "padding": "1rem 1rem",
        "background-color": "#f8f9fa",
    },
)

content = html.Div(id="page-content", style=CONTENT_STYLE)

app.layout = html.Div([dcc.Location(id="url"), sidebar,content])
home.layout =html.Div([
    html.P("Home Page"),
    dcc.Dropdown(["DeviceList","JSP/DBEM","SmartMeter","HSM","DBEM+JSP","Solar","HeatMap","Reports","Data Hours","MetaData","Devices-Info",], id='home-dropdown'),
    html.Button('Submit', id='submit-val', n_clicks=0),
])


@app.callback(Output("page-content", "children"),[Input("url", "pathname"),Input('home-dropdown','value')])
def render_page_content(pathname,home_dropdown):
    if pathname == "/":
        return home.layout
    elif pathname == "/DeviceList" or home_dropdown=='DeviceList':
        return html.P("This is the content of DeviceList ")
    elif pathname == "/JSP/DBEM" or home_dropdown=='JSP/DBEM':
        return html.P("This is the content of JSP/DBEM")
    elif pathname == "/SmartMeter" or home_dropdown=='SmartMeter':
        return html.P("This is the content of SmartMeter")
    elif pathname == "/HSM" or home_dropdown=='HSM':
        return html.P("This is the content of HSM")
    elif pathname == "/Solar" or home_dropdown=='Solar':
        return html.P("This is the content of Solar")
    elif pathname == "/DBEM+JSP" or home_dropdown=='DBEM+JSP':
        return html.P("This is the content of DBEM+JSP")
    elif pathname == "/HeatMap" or home_dropdown=='HeatMap':
        return html.P("This is the content of HeatMap")
    elif pathname == "/Reports" or home_dropdown=='Reports':
        return html.P("This is the content of Reports")
    elif pathname == "/Data Hours" or home_dropdown=='Data Hours':
        return html.P("This is the content of Data Hours")
    elif pathname == "/MetaData" or home_dropdown=='MetaData':
        return html.P("This is the content of MetaData")
    elif pathname == "/Devices-Info" or home_dropdown=='Devices-Info':
        return html.P("This is the content of Devices-Info")

    # If the user tries to reach a different page, return a 404 message
    return html.Div(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ],
        className="p-3 bg-light rounded-3",
    )


if __name__ == "__main__":
    app.run_server(debug=True)

# %%
import dash
import dash_bootstrap_components as dbc
from dash import Input, Output, dcc, html

app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
home=dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
# the style arguments for the sidebar. We use position:fixed and a fixed width
SIDEBAR_STYLE = {
        "position": "absolute",
        "top": 0,
        "left": 0,
        "bottom": 0,
        "width": "12rem",
        "padding": "1rem 1rem",
        "background-color": "#f8f9fa",
    }

# the styles for the main content position it to the right of the sidebar and
# add some padding.
CONTENT_STYLE = {
    "margin-left": "12rem",
    "margin-right": "2rem",
    "padding": "2rem 1rem",
}

sidebar = html.Div(
    [
        html.Img(src=r"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRdXp6BcRI1EEjzO07AoWD7IzzA7P77po_UUn1rxtE&s", alt='image'),
        html.H4("Data Analyzer WebApp V5.6", className="display-4",style={"font-size": "1.5rem","color":"green"}),
        html.Hr(),
        dbc.Nav(
            [
                dbc.NavLink("Home", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/", active="exact"),
                dbc.NavLink("DeviceList", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/DeviceList", active="exact"),
                dbc.NavLink("JSP/DBEM", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/JSP/DBEM", active="exact"),
                dbc.NavLink("SmartMeter", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/SmartMeter", active="exact"),
                dbc.NavLink("HSM", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/HSM", active="exact"),
                dbc.NavLink("DBEM+JSP", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/DBEM+JSP", active="exact"),
                dbc.NavLink("Solar", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Solar", active="exact"),
                dbc.NavLink("HeatMap", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/HeatMap", active="exact"),
                dbc.NavLink("Reports", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Reports", active="exact"),
                dbc.NavLink("Data Hours", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Data Hours", active="exact"),
                dbc.NavLink("MetaData", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/MetaData", active="exact"),
                dbc.NavLink("Devices-Info", style={'fontSize':'1rem','boder':'0','padding':'0'}, href="/Devices-Info", active="exact")
                
            ],
            vertical=True,
            pills=True,
        ),
    ],
    style=SIDEBAR_STYLE,
)


app.layout = html.Div([dcc.Location(id="url"), 
                       sidebar,
                       html.Div(id="page-content", style=CONTENT_STYLE),
                       html.Div(id="page1-content", style=CONTENT_STYLE)
                      ])
home.layout =html.Div([
    html.P("Home Page"),
    #dcc.Dropdown(["DeviceList","JSP/DBEM","SmartMeter","HSM","DBEM+JSP","Solar","HeatMap","Reports","Data Hours","MetaData","Devices-Info",], id='home-dropdown',value='Solar'),
    html.Div([
            dcc.Dropdown(
                id='dropdown1',
                options=[{'label': i, 'value': i} for i in range(1,10)],
            )
        ],
        style={'width': '48%', 'display': 'inline-block'}),

    html.Div([
            dcc.Dropdown(
                id='dropdown2',
                options=[{'label': i, 'value': i} for i in range(10,20)],
            )
        ],style={'width': '48%', 'float': 'right', 'display': 'inline-block'}),
    
    #html.Button('Submit', id='submit-val', n_clicks=0),
])
# @home.callback(Output("drop", "children"),[Input("home-dropdown", "value")])
# def update_page(value):
#     return "Selected {}".format(value)
#     if home_dropdown=='DeviceList':
#         return html.P("This is the content of DeviceList ")
#     elif home_dropdown=='JSP/DBEM':
#         return html.P("This is the content of JSP/DBEM")
#     elif home_dropdown=='SmartMeter':
#         return html.P("This is the content of SmartMeter")
#     elif home_dropdown=='HSM':
#         return html.P("This is the content of HSM")
#     elif home_dropdown=='Solar':
#         return html.P("This is the content of Solar")
#     elif home_dropdown=='DBEM+JSP':
#         return html.P("This is the content of DBEM+JSP")
#     elif home_dropdown=='HeatMap':
#         return html.P("This is the content of HeatMap")
#     elif  home_dropdown=='Reports':
#         return html.P("This is the content of Reports")
#     elif  home_dropdown=='Data Hours':
#         return html.P("This is the content of Data Hours")
#     elif home_dropdown=='MetaData':
#         return html.P("This is the content of MetaData")
#     elif  home_dropdown=='Devices-Info':
#         return html.P("This is the content of Devices-Info")
    
    
@app.callback(Output("page-content", "children"),
              [Input("url", "pathname")])
def render_page_content(pathname):
    if pathname == "/":
        return home.layout
    elif pathname == "/DeviceList" :
        return html.P("This is the content of DeviceList ")
    elif pathname == "/JSP/DBEM" :
        return html.P("This is the content of JSP/DBEM")
    elif pathname == "/SmartMeter" :
        return html.P("This is the content of SmartMeter")
    elif pathname == "/HSM" :
        return html.P("This is the content of HSM")
    elif pathname == "/Solar" :
        return html.P("This is the content of Solar")
    elif pathname == "/DBEM+JSP" :
        return html.P("This is the content of DBEM+JSP")
    elif pathname == "/HeatMap" :
        return html.P("This is the content of HeatMap")
    elif pathname == "/Reports" :
        return html.P("This is the content of Reports")
    elif pathname == "/Data Hours" :
        return html.P("This is the content of Data Hours")
    elif pathname == "/MetaData" :
        return html.P("This is the content of MetaData")
    elif pathname == "/Devices-Info" :
        return html.P("This is the content of Devices-Info")

    # If the user tries to reach a different page, return a 404 message
    return html.Div(
        [
            html.H1("404: Not found", className="text-danger"),
            html.Hr(),
            html.P(f"The pathname {pathname} was not recognised..."),
        ],
        className="p-3 bg-light rounded-3",
    )


if __name__ == "__main__":
    app.run_server(debug=True)

# %%
help(dcc.Dropdown)
